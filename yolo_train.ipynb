# %%
# !pip install ultralytics
# !pip install -U ipywidgets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.5/783.5 kB 10.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 2.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 44.6 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 3.0.9
#     Uninstalling jupyterlab-widgets-3.0.9:
#       Successfully uninstalled jupyterlab-widgets-3.0.9
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
# ...

# %%
# !pip3 uninstall wandb -y
# Out:
# Found existing installation: wandb 0.17.0
# Uninstalling wandb-0.17.0:
#   Successfully uninstalled wandb-0.17.0

# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO("yolov8m-seg.pt")  # ou choisir "yolov8m.pt ici ?"

# Train the model
results = model.train(data="/kaggle/input/partition-line-detection/yolo/line_detect.yaml", epochs=100, imgsz=32)
# Out:
# ...
# 100%|██████████| 52.4M/52.4M [00:00<00:00, 76.0MB/s]
# Ultralytics YOLOv8.2.36 🚀 Python-3.10.13 torch-2.1.2+cpu CPU (Intel Xeon 2.20GHz)
# ...

# %%
model.export()
# Out:
# Ultralytics YOLOv8.2.36 🚀 Python-3.10.13 torch-2.1.2+cpu CPU (Intel Xeon 2.20GHz)
# YOLOv8m-seg summary (fused): 245 layers, 27222963 parameters, 0 gradients, 110.0 GFLOPs
#
# PyTorch: starting from 'runs/segment/train/weights/best.pt' with input shape (1, 3, 32, 32) BCHW and output shape(s) ((1, 37, 21), (1, 32, 8, 8)) (52.2 MB)
#
# TorchScript: starting export with torch 2.1.2+cpu...
# TorchScript: export success ✅ 2.4s, saved as 'runs/segment/train/weights/best.torchscript' (104.3 MB)
#
# Export complete (4.4s)
# Results saved to /kaggle/working/runs/segment/train/weights
# Predict:         yolo predict task=segment model=runs/segment/train/weights/best.torchscript imgsz=32
# Validate:        yolo val task=segment model=runs/segment/train/weights/best.torchscript imgsz=32 data=/kaggle/input/partition-line-detection/yolo/line_detect.yaml
# Visualize:       https://netron.app
# 'runs/segment/train/weights/best.torchscript'

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
model = YOLO("/kaggle/working/runs/segment/train/weights/best.pt")

# %%
img_dir ='/kaggle/input/partition-png-files/png_files/'

# %%
img_list = os.listdir(img_dir)
img_list[2]
# Out:
# '000106087-1_1_1.png'

# %%
image = mpimg.imread(img_dir + img_list[2])
plt.imshow(image)

# %%
model(img_dir + img_list[11])
# Out:
# image 1/1 /kaggle/input/partition-png-files/png_files/220000619-1_3_1.png: 32x32 (no detections), 30.4ms
# Speed: 0.3ms preprocess, 30.4ms inference, 0.2ms postprocess per image at shape (1, 3, 32, 32)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'line'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
# ...
